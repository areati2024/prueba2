# %% [markdown]
# ### 1- Se cargan las librerías necesarias y se defeinen variables temporales que se utilizarán en secciones posteriores de este código.

# %%
from ast import If
from calendar import day_abbr
from datetime import datetime
import calendar
import pandas as pd
import numpy as np

day = datetime.now().day
day = str(day).zfill(2)
month = datetime.now().month
year = datetime.now().year
lastday = calendar.monthrange(year, month)
day = str(lastday[1])
month = str(month).zfill(2)

# %% [markdown]
# ### 2- Se definen diccionarios que se utilizar para buscar información.

# %%
colaboradores=  { ## 'RUT' : ['CC'[0] , 'AFP'[1] , 'codigo afp'[2] , 'Isapre'[3], 'codigo isapre'[04]],
    '17242402-3' : ['4215' , 'Habitat'  ,'96981130-8' , 'Banmedica'  ,'96572800-7'], ## ABNER ROBLES VENEGAS
    '19185762-3' : ['4217' , 'Planvital','98000900-9' , 'Cruz Blanca','96501450-0'], ## NATALIA ALEJANDRA ARANEDA RAIMAN
    '19081737-7' : ['4005' , 'Uno'      ,'76960424-3' , 'Fonasa'     ,'61533000-0'], ## TRINIDAD RICKE ZEGERS
    '16098709-k' : ['4005' , 'Cuprum'   ,'98001000-7' , 'Cruz Blanca','96501450-0'], ## CONSUELO MARTÍNEZ DE LA FUENTE
    '12041826-2' : ['4213' , 'Provida'  ,'98000400-7' , 'Consalud'   ,'89758200-7'], ## ELIZABETH ALEJANDRA DE LA CUADRA VILLALOBOS
    '13433376-6' : ['4210' , 'Provida'  ,'98000400-7' , 'Colmena'    ,'94954000-6'], ## FELIPE COX MARDONES
    '16359952-k' : ['4211' , 'Modelo'   ,'76762250-3' , 'Colmena'    ,'94954000-6'], ## FELIPE ANDRÉS CONTRERAS WEITZ
    '14163753-3' : ['4214' , 'Capital'  ,'98000000-1' , 'Colmena'    ,'94954000-6'], ## FRANCISCA DELFINA BRAVO ALMENDRAS
    '14706134-k' : ['4220' , 'Capital'  ,'98000000-1' , 'Banmedica'  ,'96572800-7'], ## GERMAN ALEJANDRO GONZALEZ MORBIDONI
    '11642192-5' : ['4203' , 'Provida'  ,'98000400-7' , 'Fonasa'     ,'61533000-0'], ## GUILLERMO ALEJANDRO GODOY BRAVO
    '12720688-0' : ['4240' , 'Capital'  ,'98000000-1' , 'Colmena'    ,'94954000-6'], ## JOAQUIN ANDRÉS ALVAREZ LAGOS
    '24984325-3' : ['4300' , 'Planvital','98000900-9' , 'Consalud'   ,'89758200-7'], ## Marlis de los Angeles Piñero Vallés
    '13888667-0' : ['4004' , 'Habitat'  ,'96981130-8' , 'Consalud'   ,'89758200-7'], ## MYRIAM LUZ MEDINA GONZALEZ
    '16301334-7' : ['4216' , 'Cuprum'   ,'98001000-7' , 'Colmena'    ,'94954000-6'], ## SEBASTIÁN ANDRÉS PÉREZ VALENZUELA
    '15376720-3' : ['4200' , 'Habitat'  ,'96981130-8' , 'Colmena'    ,'94954000-6'], ## TAHÍA TAMARA PÉREZ AROS
    '17141837-2' : ['4250' , 'Habitat'  ,'96981130-8' , 'Banmedica'  ,'96572800-7'], ## JORGE BRUNO PONCE NAVARRETE
    '17624062-8' : ['4212' , 'Habitat'  ,'96981130-8' , 'Consalud'   ,'89758200-7'], ## ALEJANDRA ANDREA FREX HENRÍQUEZ
    '19618161-k' : ['4207' , 'Modelo'   ,'76762250-3' , 'Consalud'   ,'89758200-7'], ## VALENTINA FRANCISCA FERNÁNDEZ FLAMM
    '26123890-k' : ['4100' , 'Planvital','98000900-9' , 'VidaTRes'   ,'96502530-8'], ## Ana del Pilar Cabrera Pacheco
    '14364749-8' : ['4007' , 'Habitat'  ,'96981130-8' , 'Fonasa'     ,'61533000-0'], ## CLAUDIA ARACELLY ÁLVAREZ PALMA
    '18022231-6' : ['4218' , 'Modelo'   ,'76762250-3' , 'Colmena'    ,'94954000-6'], ## MATÍAS ANDRES BURGOS RUIZ-TAGLE
    '13055563-2' : ['4219' , 'Provida'  ,'98000400-7' , 'Fonasa'     ,'61533000-0'], ## RODRIGO FELIPE CARRERA MACHUCA
    '14436097-4' : ['4230' , 'Planvital','98000900-9' , 'Banmedica'  ,'96572800-7'], ## Gustavo Antonio Muñoz
    '15999839-8' : ['4252' , 'Habitat'  ,'96981130-8' , 'Fonasa'     ,'61533000-0'], ## NATALIE CAROLINA ROZAS FARÍAS
    '26212913-6' : ['4251' , 'Planvital','98000900-9' , 'Colmena'    ,'94954000-6'], ## NOHELIA ELISA PIÑA GONZALEZ
    '18573140-5' : ['4223' , 'Modelo'   ,'76762250-3' , 'Cruz Blanca','96501450-0'], ## ALONSO EDUARDO ORO ÁLVAREZ
    '8660065-k' :  ['4224' , 'Capital'  ,'98000000-1' , 'Cruz Blanca' ,'96501450-0'], ## GILBERTO DARIO PALMA MARCHANT
    '16126462-8' : ['4216' , 'Capital'  ,'98000000-1' , 'Cruz Blanca' ,'96501450-0'], ## JOHAN ALEJANDRO ALCANTARA MORALES
    '25963669-8' : ['4225' , 'Planvital','98000900-9' , 'Colmena'    ,'94954000-6'], ## OMAR EDILBERTO DÍAZ CONTRERAS
    '16193902-1' : ['4227' , 'Provida'  ,'98000400-7' , 'Fonasa'     ,'61533000-0'], ## JIMMY ANDRES CASTILLO MUÑOZ
    '25899854-5' : ['4250' , 'Modelo'   ,'76762250-3' , 'Banmedica'  ,'96572800-7'], ## LEONARDO ARGENIS
    '15821822-4' : ['4252' , 'Habitat'  ,'96981130-8' , 'Fonasa'     ,'61533000-0'], ## ESTEFANIA COLOMBO
    '14164198-0' : ['4000' , 'Cuprum'   ,'98001000-7' , 'Nueva MasVida' ,'96504160-5'], ## PABLO ARIEL CATRIL
    '17325593-4' : ['4218' , 'Cuprum'   ,'98001000-7' , 'Consalud'   ,'89758200-7'], ## Daniela Rosales
    '25841088-2' : ['4227' , 'Provida'  ,'98000400-7' , 'Cruz Blanca' ,'96501450-0'], ## Jessi Sosa
    '10031618-8' : ['4226' , 'Capital'  ,'98000000-1' , 'VidaTres'   ,'96502530-8'], ## GONZALO ARIEL CERDA NARANJO
    '19545869-3' : ['4250' , 'Modelo'   ,'76762250-3' , 'Fonasa'     ,'61533000-0'] ## HARLES ORION LATORRE SUITT

}
#Clave: 40 si va al debe y 31 si va haber
item_cc  ={ ## item : ['clave'[0],'codigo/cuenta'[1],'indicador'[2], 'con o no centro costos'[3],'00,C O 00,D'[4]],
 'Sobregiro' :                                   ['40','431400','','cncc',',00D'],
 'Sueldo Base' :                                 ['40','431400','','cncc',',00D'],
 'Gratificación' :                               ['40','437100','','cncc',',00D'],
 'Gratificación Mensual' :                       ['40','437100','','cncc',',00D'],
 'Gratificación 2023' :                          ['40','437100','','cncc',',00D'],
 'Gratificación 2022' :                          ['40','437100','','cncc',',00D'],
 'Gratif Mayo 2023' :                            ['40','437100','','cncc',',00D'],
 'Gratif Junio 2023' :                           ['40','437100','','cncc',',00D'],
 'Gratif Abril 2023' :                           ['40','437100','','cncc',',00D'],
 'Gratif Julio 2023' :                           ['40','437100','','cncc',',00D'],
 'Gratif Agosto 2023' :                          ['40','437100','','cncc',',00D'],
 'Gratif Febrero 2023' :                         ['40','437100','','cncc',',00D'],
 'Gratif Marzo 2023' :                           ['40','437100','','cncc',',00D'],
 'Gratif Enero 2023' :                           ['40','437100','','cncc',',00D'],
 'Aguinaldo navidad' :                           ['40','431500','','cncc',',00D'],
 'Aguinaldo Fiestas Patrias' :                   ['40','431500','','cncc',',00D'],
 'Bono Liquido Calculado' :                      ['40','431500','','cncc',',00D'],
 'Retroactivo Variable Y Bono' :                 ['40','431500','','cncc',',00D'],
 'Retroactivo Fijo' :                            ['40','431500','','cncc',',00D'],
 'Premio mes' :                                  ['40','431500','','cncc',',00D'],
 'Bono Unico' :                                  ['40','431500','','cncc',',00D'],
 'Bono Spot' :                                   ['40','431500','','cncc',',00D'],
 'Aguinaldo' :                                   ['40','431500','','cncc',',00D'],
 'Bono Bencina' :                                ['40','431500','','cncc',',00D'],
 'Bono Mensual':                                 ['40','431500','','cncc',',00D'],
 'Bono Semestral':                               ['40','431500','','cncc',',00D'],
 'Bono Escolar' :                                ['40','431500','','cncc',',00D'],
 'Bono Desempeno Anual' :                        ['40','431500','','cncc',',00D'],
 'Bono Regional' :                               ['40','431500','','cncc',',00D'],
 'Bono Trimestral' :                             ['40','431500','','cncc',',00D'],
 'Bono bencina' :                                ['40','431500','','cncc',',00D'],
 'Bono Bencina Junio':                           ['40','431500','','cncc',',00D'],
 'Bono Internet' :                               ['40','431500','','cncc',',00D'],
 'Bono Telefono'  :                              ['40','431500','','cncc',',00D'],
 'Bono Celular'  :                               ['40','431500','','cncc',',00D'],
 'Bono Internet Mayo':                           ['40','431500','','cncc',',00D'],
 'Bono Sala Cuna' :                              ['40','431500','','cncc',',00D'],
 'Bono Vacaciones' :                             ['40','431500','','cncc',',00D'],
 'Bono Reliquidado Actualizado' :                ['40','431500','','cncc',',00D'],
 'Bono Especial' :                               ['40','431500','','cncc',',00D'],
 'Bono Licencia Medica' :                        ['40','431500','','cncc',',00D'],
 'Bono 10 Años' :                                ['40','431500','','cncc',',00D'],
 'Bono Celular' :                                ['40','431500','','cncc',',00D'],
 'Vacaciones Pendientes' :                       ['40','431500','','cncc',',00D'], #Agregado por Nicolás Pacheco. No original
 'Indemnizacion por Vacaciones Pendientes' :     ['40','431500','','cncc',',00D'],
 'Indemnización Voluntaria' :                    ['40','431500','','cncc',',00D'],
 'Indemnización Legal Años de Servicio' :        ['40','431500','','cncc',',00D'],
 'Indemnización Sustitutiva Previo Aviso' :      ['40','431500','','cncc',',00D'],
 'Premio mes' :                                  ['40','431500','','cncc',',00D'],
 'Diferencia sueldo' :                           ['40','431500','','cncc',',00D'],
 'Diferencia Pago Licencia Medica' :             ['40','431500','','cncc',',00D'],
 'Diferencial Pago Licencia Medica' :            ['40','431500','','cncc',',00D'],
 'Premio' :                                      ['40','431500','','cncc',',00D'],
 'Premio Antiguedad' :                           ['40','431500','','cncc',',00D'],
 'Mes de Aviso' :                                ['40','431500','','cncc',',00D'],
 'Bono Anual VAP Reliquidado' :                  ['40','431500','','cncc',',00D'],
 'Bono Único Reliquidado' :                      ['40','431500','','cncc',',00D'],

 'Cotiz. Prev. Voluntaria':                      ['31','Rut-de-AFP','','',',00C'],
 'APVC Debe':                                    ['40','76011193-7','','',',00C'],
 'APVC Haber':                                   ['31','76011193-7','','',',00C'],
 'Prevision (Habitat)'  :                        ['31','96981130-8','','',',00C'],                       
 'Prevision (PlanVital)':                        ['31','98000900-9','','',',00C'],                                              
 'Prevision (ProVida)'  :                        ['31','98000400-7','','',',00C'],                           
 'Prevision (Cuprum)'   :                        ['31','98001000-7','','',',00C'],                         
 'Prevision (Capital)'  :                        ['31','98000000-1','','',',00C'],                                                                          
 'Prevision (Modelo)'   :                        ['31','76762250-3','','',',00C'],                                                                                        
 'Prevision (Uno)'      :                        ['31','76960424-3','','',',00C'],
 'Prevision Reliq. (Habitat)'  :                 ['31','96981130-8','','',',00C'],
 'Prevision Reliq. (PlanVital)':                 ['31','98000900-9','','',',00C'],  
 'Prevision Reliq. (ProVida)'  :                 ['31','98000400-7','','',',00C'],
 'Prevision (Cuprum)'          :                 ['31','98001000-7','','',',00C'],                                                                            
 'Prevision Reliq. (Capital)'  :                 ['31','98000000-1','','',',00C'],
 'Prevision Reliq. (Modelo)'   :                 ['31','76762250-3','','',',00C'], 
 'Prevision Reliq. (Uno)'      :                 ['31','76960424-3','','',',00C'],
 'Prevision Reliq. (Cuprum)'      :                 ['31','76960424-3','','',',00C'],
                        
 #'Fonasa (0.55%)' :                             ['31','61533000-0','','',',00C'],  #Fonasa
 'Fonasa (3.9%)' :                               ['31','61533000-0','','',',00C'],  #Fonasa
 'Fonasa (1.0%)' :                               ['31','61533000-0','','',',00C'],  #Fonasa
 #'Valor a pagar caja (6.45%)' :                 ['31','61533000-0','','',',00C'],  #Fonasa
 'Valor a pagar caja (3.1%)' :                   ['31','61533000-0','','',',00C'],  #Fonasa
 'Valor a pagar caja Reliq. (3.1%)' :            ['31','61533000-0','','',',00C'],  #Fonasa
 'Valor a pagar caja (6.0%)' :                   ['31','61533000-0','','',',00C'],  #Fonasa
 'Valor a pagar caja Reliq. (6.0%)' :            ['31','61533000-0','','',',00C'],  #Fonasa
 'Crédito Personal Caja La Araucana' :           ['31','61533000-0','','',',00C'],  #Fonasa
 'Fonasa Reliq. (0.55%)' :                       ['31','61533000-0','','',',00C'],  #Fonasa
 'Fonasa Reliq. (1.0%)' :                        ['31','61533000-0','','',',00C'],  #Fonasa
 'Fonasa Reliq. (3.9%)' :                        ['31','61533000-0','','',',00C'],  #Fonasa
 'Valor a pagar caja Reliq. (6.45%)' :           ['31','61533000-0','','',',00C'],  #Fonasa

 'Isapre (Consalud)'   :                         ['31','89758200-7','','',',00C'],
 'Isapre (Vida Tres)'  :                         ['31','96502530-8','','',',00C'], 
 'Isapre (Colmena)'    :                         ['31','94954000-6','','',',00C'], 
 'Isapre (Cruz Blanca)':                         ['31','96501450-0','','',',00C'], 
 'Isapre (Banmedica)'  :                         ['31','96572800-7','','',',00C'], 
 'Isapre (Nueva Masvida)'  :                     ['31','96504160-5','','',',00C'], 
 'Salud Voluntaria (Consalud)'   :               ['31','89758200-7','','',',00C'],
 'Salud Voluntaria (Vida Tres)'  :               ['31','96502530-8','','',',00C'],
 'Salud Voluntaria (Colmena)'    :               ['31','94954000-6','','',',00C'],
 'Salud Voluntaria (Cruz Blanca)':               ['31','96501450-0','','',',00C'],
 'Salud Voluntaria (Banmedica)'  :               ['31','96572800-7','','',',00C'],
 'Salud Voluntaria (Nueva Masvida)'  :           ['31','96572800-7','','',',00C'],
 'Isapre Reliq. (Vida Tres)'     :               ['31','96502530-8','','',',00C'],
 'Isapre Reliq. (Cruz Blanca)'   :               ['31','96501450-0','','',',00C'],
 'Isapre Reliq. (Banmedica)'     :               ['31','96572800-7','','',',00C'],
 'Isapre Reliq. (Colmena)'       :               ['31','94954000-6','','',',00C'],
 'Isapre Reliq. (Consalud)'      :               ['31','89758200-7','','',',00C'],
 'Cesantía':                                     ['31','96981130-8','','',',00C'],
 'Cesantía Reliq.':                              ['31','96981130-8','','',',00C'],
 'Impuesto' :                                    ['31','60805000-3','','',',00C'],
 'Impuesto Reliq.' :                             ['31','60805000-3','','',',00C'], 

 'Liquido a Pago' :                              ['39','Rut-Trabaj','1','',',00C'],
 'Líquido a Recibir' :                           ['39','Rut-Trabaj','1','',',00C'],
 'Liquido Finiquito' :                           ['39','Rut-Trabaj','1','',',00C'],
 'Monto Finiquito' :                             ['39','Rut-Trabaj','1','',',00C'], #Agregado por Nicolás Pacheco. No original

 'Descuento Anticipo' :                          ['31','Rut-Trabaj','','',',00C'],
 'Anticipo Aguinaldo Septiembre' :               ['31','Rut-Trabaj','','',',00C'],
 'Anticipo Gratificación 2023' :                 ['31','Rut-Trabaj','','',',00C'],
 'Descuento Sueldo Liquido Agosto' :             ['31','Rut-Trabaj','','',',00C'],
 'Descuento Sueldo Liquido Agosto' :             ['31','Rut-Trabaj','','',',00C'],
 'Descuento Bono Vacaciones' :                   ['31','Rut-Trabaj','','',',00C'],
 'Descuento' :                                   ['31','Rut-Trabaj','','',',00C'],
 'Descuento Gratificación' :                     ['31','Rut-Trabaj','','',',00C'],
 'Otros Descuentos Finiquito' :                  ['31','Rut-Trabaj','','',',00C'],
 'Préstamo Solidario del Estado' :               ['31','Rut-Trabaj','','',',00C'],
 'Pago Gratificación 2022' :                     ['31','Rut-Trabaj','','',',00C'],

 'Cesantía Empleador':                           ['40','442001','','cncc',',00D'],
 'Cesantía Empleador Reliq.':                    ['40','442001','','cncc',',00D'],

 'Mutual':                                       ['40','442000','','cncc',',00D'],
 'Mutual Reliq.':                                ['40','442000','','cncc',',00D'],

 'Seguro Invalidez':                             ['40','442000','','cncc',',00D'],
 'Seguro Invalidez Reliq.':                      ['40','442000','','cncc',',00D'], 

 'Seguro Invalidez (Habitat)'  :                 ['31','96981130-8','','',',00C'],
 'Seguro Invalidez (PlanVital)':                 ['31','98000900-9','','',',00C'],
 'Seguro Invalidez (ProVida)'  :                 ['31','98000400-7','','',',00C'],
 'Seguro Invalidez (Cuprum)'   :                 ['31','98001000-7','','',',00C'],
 'Seguro Invalidez (Capital)'  :                 ['31','98000000-1','','',',00C'],
 'Seguro Invalidez (Modelo)'   :                 ['31','76762250-3','','',',00C'],
 'Seguro Invalidez (Uno)'      :                 ['31','76960424-3','','',',00C'],
 'Seguro Invalidez Reliq. (Habitat)'  :          ['31','96981130-8','','',',00C'],
 'Seguro Invalidez Reliq. (PlanVital)':          ['31','98000900-9','','',',00C'],
 'Seguro Invalidez Reliq. (ProVida)'  :          ['31','98000400-7','','',',00C'],
 'Seguro Invalidez Reliq. (Cuprum)'   :          ['31','98001000-7','','',',00C'],
 'Seguro Invalidez Reliq. (Capital)'  :          ['31','98000000-1','','',',00C'],
 'Seguro Invalidez Reliq. (Modelo)'   :          ['31','76762250-3','','',',00C'],
 'Seguro Invalidez Reliq. (Uno)'      :          ['31','76960424-3','','',',00C'],
}

item_cc2 ={ ## item : ['clave'[0],'codigo/cuenta'[1],'indicador'[2], 'con o no centro costos'[3],'00,C O 00,D'[4]],
 'Descuento Anticipo' :                          ['21','Rut-Trabaj','','',',00C'],
 'Descuento' :                                   ['21','Rut-Trabaj','','',',00C'],
 
 'Cesantía Empleador':                           ['31','96981130-8','','',',00C'],
 'Cesantía Empleador Reliq.':                    ['31','96981130-8','','',',00C'],

 'Mutual':                                       ['31','70285100-9','','',',00C'],
 'Mutual Reliq.':                                ['31','70285100-9','','',',00C'],

}

# %% [markdown]
# ### 3- Se cargan los archivos excel que contienen información sobre los finiquitos, se combinan y se adaptan al formato del excel "Contabilidad...".

# %%
# Actulizar tanto el nombre del archivo excel como la que lo contine!
finiqA = pd.read_excel(r"C:\Users\delle\Mis Carpetas\3_Código TESA\2024-01\Contabilidad-Finiquitos-TESA TAPE CHILE S A-Agosto-2023.xlsx", index_col = False)
finiqA['Debe'].fillna(0, inplace=True)
finiqA['Haber'].fillna(0, inplace=True)
finiqA['Monto'] = finiqA['Debe'] + finiqA['Haber']
finiqB = pd.read_excel(r"C:\Users\delle\Mis Carpetas\3_Código TESA\2023-10-03 Finiquitos.xlsx", index_col = False, header=3)
finiqB.rename(columns={'Monto sin remuneración pendiente': 'Monto'}, inplace=True)

finiq = finiqA.merge(finiqB, on="Monto", how='left')
finiq.rename(columns = {'Apellido':'APELLIDOS','Nombre':'NOMBRES','Cargo':'CARGO','Numero cuenta contable':'CUENTA CONTABLE', 'Debe':'VALOR DEBE', 'Haber':'VALOR HABER', 'Centro de Costo':'CENTRO COSTOS', 'Nombre Cuenta Contable': 'DESCRIPCIÓN CONCEPTO'}, inplace = True)
finiq['CODIGO CONCEPTO'] = np.nan
finiq = finiq[['RUT','APELLIDOS', 'NOMBRES', 'CARGO', 'CUENTA CONTABLE', 'VALOR DEBE', 'VALOR HABER', 'CENTRO COSTOS','DESCRIPCIÓN CONCEPTO', 'CODIGO CONCEPTO']]

#display(finiq)

# %% [markdown]
# ### 4- Se carga el archivo excel "Contabilidad..." de Buk y se combina con el df finiq.

# %%
# Actulizar tanto el nombre del archivo excel como la que lo contine!
conta = pd.read_excel (r"C:\Users\delle\Mis Carpetas\3_Código TESA\2023-12\Contabilidad-TESA TAPE CHILE S A-2023-12-01.xlsx", skiprows=5, index_col = False)

archivo = pd.concat([conta, finiq], ignore_index=True)
#display(archivo)

# %% [markdown]
# ### 5- Se manipula/limpia el archivo resultante y finalmente se le agrega una columna de ranking.

# %%
archivo.rename(columns = {'RUT':'rutTrabajador','DESCRIPCIÓN CONCEPTO':'item','VALOR DEBE':'debe','VALOR HABER':'haber'}, inplace = True)
archivo['debe'] = archivo['debe'].replace(np.nan,0)
archivo['haber'] = archivo['haber'].replace(np.nan,0)
archivo.loc[(archivo['debe'] > 0) & (archivo['item'] == 'APVC'), 'item'] = 'APVC Debe'
archivo.loc[(archivo['haber'] > 0) & (archivo['item'] == 'APVC'), 'item'] = 'APVC Haber'
archivo['rutTrabajador'] = archivo['rutTrabajador'].str.replace('.','')

archivo['ranking'] = archivo.groupby(['rutTrabajador','item'])['haber'].rank('dense', ascending = False)
#Cada grupo es una combinación única de rutTrabajador-item. Dado que hay algunas filas, con dicha combinación, que se repiten en
#el excel, la fila que tenga mayor "haber" tendrá el ranking 1, mientras que la menor o las menores, tendrán un ranking mayor

#nombre_archivo = "modifica2.xlsx"  # Nombre del archivo de destino
#archivo.to_excel(nombre_archivo, index=False)
# Out:
# C:\Users\delle\AppData\Local\Temp\ipykernel_19340\1680478650.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   archivo['rutTrabajador'] = archivo['rutTrabajador'].str.replace('.','')

# %% [markdown]
# ### 6- Se crea un data frame vacío, con un determinado formato de columnas.

# %%
df= pd.DataFrame(columns=['colrut','INTERFACE PAYROLL','clave/codigo_cuenta','INDICADOR','centro_costos','saldo','COLA'])

# %% [markdown]
# ### 7- Según determinados criterios, se pobla el data frame "df".

# %%
for i in range(len(archivo)):
    item = archivo.loc[i,'item']
    if archivo.loc[i,'haber'] == 0: 
        saldo = archivo.loc[i,'debe']
    else:
        saldo = archivo.loc[i,'haber']

    if archivo.loc[i,'ranking'] == 1 :
        centro_costos = item_cc[item][3]
        
        if  archivo.loc[i,'item'] in item_cc.keys():
            clave = item_cc[item][0]
            codigo_cuenta = item_cc[item][1]
            cola = item_cc[item][4]
        else:
            clave = 'clave no existe'
            codigo_cuenta = 'codigo no existe'
            cola = 'no existe'
    else :
        centro_costos = item_cc2[item][3]
        if  archivo.loc[i,'item'] in item_cc2.keys():
            clave = item_cc2[item][0]
            codigo_cuenta = item_cc2[item][1]
            cola = item_cc2[item][4]
        else:
            clave = 'clave no existe'
            codigo_cuenta = 'codigo no existe'
            cola = 'no existe'
        

    if  codigo_cuenta =='Rut-de-AFP':
        codigo_cuenta = colaboradores[archivo.loc[i,'rutTrabajador']][2]
    elif codigo_cuenta =='Rut-isapre':
        codigo_cuenta = colaboradores[archivo.loc[i,'rutTrabajador']][4]
    elif codigo_cuenta =='Rut-Trabaj':
        codigo_cuenta = archivo.loc[i,'rutTrabajador']
    else :
        codigo_cuenta = codigo_cuenta

   
    if centro_costos == 'cncc':
        centro_costos = colaboradores[archivo.loc[i,'rutTrabajador']][0]
    else :
        centro_costos =''

    df.loc[i,'colrut'] = archivo.loc[i,'rutTrabajador']+ (day) + (month) + str(year) + 'SA0175' + (day) + (month) + str(year) + (month) + 'CLP'
    df.loc[i,'INTERFACE PAYROLL'] = 'INTERFACE PAYROLL'
    df.loc[i,'clave/codigo_cuenta'] = clave  + codigo_cuenta
    df.loc[i,'INDICADOR'] = item_cc[item][2] ##if item_cc[item][2] != '' else '        '
    df.loc[i,'centro_costos'] = centro_costos ##if centro_costos != '' else '      '
    df.loc[i,'saldo'] = saldo
    df.loc[i,'COLA'] = cola

display(df.head(10))
# Out:
#                                   colrut  INTERFACE PAYROLL  \
# 0  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 1  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 2  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 3  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 4  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 5  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 6  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 7  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 8  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
# 9  14164198-031102023SA01753110202310CLP  INTERFACE PAYROLL
#
#   clave/codigo_cuenta INDICADOR centro_costos      saldo  COLA
# 0            40431400                    4000  5250000.0  ,00D
# 1            40431500                    4000    18750.0  ,00D
# 2            40442000                    4000    55427.0  ,00D
# ...

# %% [markdown]
# ### 8-  Se traslada la información del df a un archivo txt con determinado orden y formato.

# %%
df = df.sort_values(by = ['colrut','clave/codigo_cuenta'], ascending = True).reset_index(drop = True)
num_doc = str(year) + str(month)
nombre_doc = num_doc + '_centralizacion contable.txt'
df['saldo'] = df['saldo'].astype(int)
with open(nombre_doc, 'w') as f:
    for i in range(len(df)):
        if len(df.loc[i,'colrut']) == 36:
            f.write(' ')
            f.write(df.loc[i,'colrut'])
        else:
            f.write(df.loc[i,'colrut'])
        f.write('                  ')
        f.write(df.loc[i,'INTERFACE PAYROLL'])
        f.write('        ')
        f.write(df.loc[i,'clave/codigo_cuenta'])
        if len(df.loc[i,'clave/codigo_cuenta']) == 11:
            f.write(' ')
        if df.loc[i,'INDICADOR'] == '' and df.loc[i,'centro_costos'] == '':
            if len(str(df.loc[i,'saldo'])) == 3:
                f.write('                           ')    
            elif len(str(df.loc[i,'saldo'])) == 4:
                f.write('                          ')  
            elif len(str(df.loc[i,'saldo'])) == 5:
                f.write('                         ')  
            elif len(str(df.loc[i,'saldo'])) == 6:
                f.write('                        ')
            elif len(str(df.loc[i,'saldo'])) == 7:
                f.write('                       ')  
            else:
                f.write('                     ')
            f.write(str(df.loc[i,'saldo']))
            f.write(df.loc[i,'COLA'])
            f.write('\n')
          
        elif df.loc[i,'INDICADOR'] == '1' and df.loc[i,'centro_costos'] == '':
            f.write('       ')
            f.write(df.loc[i,'INDICADOR'])
            if len(str(df.loc[i,'saldo'])) == 3:
                f.write('                   ')
            elif len(str(df.loc[i,'saldo'])) == 4:
                f.write('                  ')
            elif len(str(df.loc[i,'saldo'])) == 5:
                f.write('                 ')
            elif len(str(df.loc[i,'saldo'])) == 6:
                f.write('                ')    
            elif len(str(df.loc[i,'saldo'])) == 7:
                f.write('               ')  
            elif len(str(df.loc[i,'saldo'])) == 8:
                f.write('              ')  
            else:
                f.write('           ')
            f.write(str(df.loc[i,'saldo']))
            f.write(df.loc[i,'COLA'])
            f.write('\n')
            
        else:
            f.write('            ')
            f.write(df.loc[i,'centro_costos'])
            if len(str(df.loc[i,'saldo'])) == 3:
                f.write('               ')    
            elif len(str(df.loc[i,'saldo'])) == 4:
                f.write('              ')  
            elif len(str(df.loc[i,'saldo'])) == 5:
                f.write('             ')  
            elif len(str(df.loc[i,'saldo'])) == 6:
                f.write('            ')
            elif len(str(df.loc[i,'saldo'])) == 7:
                f.write('           ')  
            elif len(str(df.loc[i,'saldo'])) == 8:
                f.write('          ')  
            else:
                f.write('               ')
            f.write(str(df.loc[i,'saldo']))
            f.write(df.loc[i,'COLA'])
            f.write('\n')

# %% [markdown]
# ### 9- Se imprimen métricas para checkear la información entregada.

# %%
# -> aqui esta el archivo C:\Data Governance\Bots\python
#Checks la resta debe der Cero
#el valor de 40 debe ser el mismo que la suma del debe en el excel 
print('31+39:',df[(df['clave/codigo_cuenta'].str[:2]=='31') | (df['clave/codigo_cuenta'].str[:2]=='39')].saldo.astype(float).sum())
print('40:',df[(df['clave/codigo_cuenta'].str[:2]=='40')].saldo.astype(float).sum())
print('resta:',df[(df['clave/codigo_cuenta'].str[:2]=='31') | (df['clave/codigo_cuenta'].str[:2]=='39')].saldo.astype(float).sum() - df[(df['clave/codigo_cuenta'].str[:2]=='40')].saldo.astype(float).sum())
# Out:
# 31+39: 112487978.0
# 40: 112487978.0
# resta: 0.0
